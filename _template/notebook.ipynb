# %% [markdown]
# # NNN — Solution Name
#
# **Category:** `category-tag`
# **Core idea:** One sentence.
# **Best result:** XX.XX% on DATASET
#
# ---
#
# ## Table of Contents
# 1. Setup & Imports
# 2. Algorithm Explanation
# 3. Training Run
# 4. Analysis & Visualizations
# 5. Comparison vs Backprop
# 6. Conclusions & Next Steps

# %% [markdown]
# ## 1. Setup & Imports

# %%
import sys, os
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# Import the core implementation
sys.path.insert(0, os.path.dirname(os.path.abspath('__file__')))
from core import *  # TODO: import your specific classes

# Shared benchmarks
sys.path.insert(0, os.path.join('..', '..', 'benchmarks'))
from utils import get_dataset, evaluate, count_params, DEVICE

matplotlib.rcParams['figure.figsize'] = (12, 5)
matplotlib.rcParams['font.size'] = 11
print(f'Device: {DEVICE}')

# %% [markdown]
# ## 2. Algorithm Explanation
#
# ### Core Equation
#
# $$\text{TODO: LaTeX equation}$$
#
# ### Why This Might Work
#
# TODO: explain the intuition

# %% [markdown]
# ## 3. Training Run

# %%
# Load data
train_loader, test_loader, info = get_dataset('mnist')
print(f'Dataset info: {info}')

# Create model
# model = YourNetwork(...).to(DEVICE)
# print(f'Params: {count_params(model)}')

# %%
# Training loop
import time

history = {'epoch': [], 'loss': [], 'accuracy': [], 'time': []}
N_EPOCHS = 50

for ep in range(1, N_EPOCHS + 1):
    t0 = time.time()
    # loss = model.train_epoch(train_loader)
    # acc = model.evaluate(test_loader)
    dt = time.time() - t0
    # history['epoch'].append(ep)
    # history['loss'].append(loss)
    # history['accuracy'].append(acc)
    # history['time'].append(dt)
    # if ep <= 10 or ep % 5 == 0:
    #     print(f'Ep {ep:3d} | Loss {loss:.4f} | Acc {acc*100:.2f}% | {dt:.1f}s')

# %% [markdown]
# ## 4. Analysis & Visualizations

# %%
# TODO: Plot accuracy curve, loss curve, timing
# TODO: Visualize whatever is unique to this algorithm
# (entropy distributions, weight patterns, attention maps, spike rates, etc.)

# fig, axes = plt.subplots(1, 3, figsize=(16, 5))
# ...
# plt.savefig('results/training_dynamics.png', dpi=150, bbox_inches='tight')
# plt.show()

# %% [markdown]
# ## 5. Comparison vs Backprop
#
# Fair comparison: same architecture, same dataset, same epochs.

# %%
# TODO: Train backprop baseline with same architecture
# TODO: Plot side-by-side curves
# TODO: Report gap

# %% [markdown]
# ## 6. Conclusions & Next Steps
#
# ### Results
# | Dataset | This algo | Backprop | Gap |
# |---------|-----------|----------|-----|
# | MNIST | TODO% | 98.04% | TODO |
#
# ### Key Insight
# TODO
#
# ### Next Steps
# See README.md → Next Steps / Roadmap
